# %% [markdown]
# # Pert 3

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
value = 75
if value >=90:
    grade = "A"
elif value >= 80:
    grade = "B"
else :
    grade = "E"

print("Grade : %s" % grade)
# Out:
# Grade : E

# %%
nilai = 70
umur = 20

if nilai >= 75:
    if (umur < 20):
        print("Pass")
    else:
        print("try again")
else: 
    if(umur > 20):
        print("try again")
    else:
        print ("try again")
# Out:
# try again
